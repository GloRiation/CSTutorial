# %% [markdown]
# #  In-Class Practice of Topic 1

# %%
lastname='Chan'
title='Mr. '
fullname=title+lastname
fullname
# Out:
# 'Mr. Chan'

# %%
from scipy.stats import norm
VaR=scipy.stats.norm.ppf(0.95,1000000,500000)
VaR
pv=1-scipy.stats.norm.cdf(2.3,loc=0,scale=1)
pv
# Out:
# 1822426.813475736

# %%
import numpy as np
import matplotlib.pyplot as plt
prc_chg=np.random.normal(0,1,252)
stockprice=np.cumsum(prc_chg)
stockprice
plt.figure(figsize=(20,10))
plt.plot(stockprice,color='purple')
plt.show()
